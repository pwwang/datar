# %%
# https://dplyr.tidyverse.org/reference/across.html
import numpy

from plyrda.data import iris
from plyrda.all import *

# %%
# round not changing dtypes (Series.round)
iris >> mutate(across(c(f['Sepal.Length'], f['Sepal.Width']), round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris >> mutate(across([0, 1], round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# index is 0-based, stop of slice is included
iris >> mutate(across(f[0:f['Sepal.Width']], round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# to exclude stop of slice
iris >> mutate(across(f[0:f['Sepal.Width']:0], round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          3.5           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.2           1.3          0.2     setosa
# 3             5.0          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.5           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.4           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris >> mutate(across(where(is_double) & ~c(f['Petal.Length'], f['Petal.Width']), round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris >> mutate(Species=as_categorical(f.Species))
iris.dtypes
# Out:
# Sepal.Length     float64
# Sepal.Width      float64
# Petal.Length     float64
# Petal.Width      float64
# Species         category
# dtype: object

# %%
iris = iris >> mutate(across(where(is_categorical), as_character))
iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), mean, na_rm=True)
)
# Out:
# Sepal.Length
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2450ec1430b8> in <module>
#       1 iris >> group_by(f.Species) >> summarise(
# ----> 2     across(starts_with("Sepal"), mean, na_rm=True)
#       3 )
#
# ~/github/pipda/pipda/function.py in evaluate(self, data, context)
#      65         args = evaluate_args(self.args, data, context.args)
#      66         kwargs = evaluate_kwargs(self.kwargs, data, context.kwargs)
# ---> 67         return self.func(data, *args, **kwargs)
#      68
#      69 def _register_function_no_datarg(
#
# ~/miniconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/github/plyrda/plyrda/verbs.py in summarise(_data, _groups, *acrosses, **kwargs)
#     286     for acrs in acrosses:
#     287         if isinstance(acrs, Across):
# --> 288             across.update(acrs.evaluate(Context.EVAL, _data))
#     289         else:
#     290             across.update(acrs)
#
# ~/github/plyrda/plyrda/middlewares.py in evaluate(self, context, data)
#     133                 else:
#     134                     # otherwise, fn should handle group by itself
# --> 135                     ret[name] = fn(data, column, *self.args, **self.kwargs)
#     136
#     137         return ret
#
# ~/github/pipda/pipda/function.py in wrapper(_force_piping, *args, **kwargs)
#     108         if _force_piping or is_piping():
#     109             return Function(generic, context, args, kwargs)
# --> 110         return func(*args, **kwargs)
#     111
#     112     wrapper.register = generic.register
#
# ~/github/plyrda/plyrda/funcs.py in wrapper(_data, _column, *args, **kwargs)
#      61         args = evaluate_args(args, _data, context.args)
#      62         kwargs = evaluate_kwargs(kwargs, _data, context.kwargs)
# ---> 63         return func(series, *args, **kwargs)
#      64
#      65     @wrapper.register(DataFrameGroupBy)
#
# ~/github/plyrda/plyrda/funcs.py in mean(series, na_rm)
#     393 def mean(series: Iterable[Any], na_rm: bool = False) -> float:
#     394     print(series)
# --> 395     return numpy.nanmean(series) if na_rm else numpy.mean(series)
#     396
#     397 @register_grouped
#
# <__array_function__ internals> in nanmean(*args, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py in nanmean(a, axis, dtype, out, keepdims)
#     937     arr, mask = _replace_nan(a, 0)
#     938     if mask is None:
# --> 939         return np.mean(arr, axis=axis, dtype=dtype, out=out, keepdims=keepdims)
#     940
#     941     if dtype is not None:
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3371
#    3372     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3373                           out=out, **kwargs)
#    3374
#    3375
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), dict(mean=mean, sd=sd))
)

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), mean, _names = "mean_{_col}")
)

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), dict(mean=mean, sd=sd), _names = "{_col}.{_fn}")
)

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), [mean, sd], _names = "{_col}.fn{_fn}")
)

# %%
runif = numpy.random.default_rng(8525).random
df = DataFrame(dict(
    id=[1, 2, 3, 4], 
    w=runif(4), 
    x=runif(4), 
    y=runif(4), 
    z=runif(4)
))
df >> rowwise() >> mutate(
    sum = c_across(f.w // f.z, sum), # function has to be called inside c_across
    sd = c_across(f.w // f.z, sd)
)
