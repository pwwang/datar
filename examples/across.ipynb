# %%
# https://dplyr.tidyverse.org/reference/across.html
import numpy

from plyrda.data import iris
from plyrda.all import *

# %%
# round not changing dtypes (Series.round)
iris >> mutate(across(c(f['Sepal.Length'], f['Sepal.Width']), round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris >> mutate(across([0, 1], round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# index is 0-based, stop of slice is included
iris >> mutate(across(f[0:f['Sepal.Width']], round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# to exclude stop of slice
iris >> mutate(across(f[0:f['Sepal.Width']:0], round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          3.5           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.2           1.3          0.2     setosa
# 3             5.0          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.5           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.4           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris >> mutate(across(where(is_double) & ~c(f['Petal.Length'], f['Petal.Width']), round))
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.0          4.0           1.4          0.2     setosa
# 1             5.0          3.0           1.4          0.2     setosa
# 2             5.0          3.0           1.3          0.2     setosa
# 3             5.0          3.0           1.5          0.2     setosa
# 4             5.0          4.0           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           7.0          3.0           5.2          2.3  virginica
# 146           6.0          2.0           5.0          1.9  virginica
# 147           6.0          3.0           5.2          2.0  virginica
# 148           6.0          3.0           5.4          2.3  virginica
# 149           6.0          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris >> mutate(Species=as_categorical(f.Species))
iris.dtypes
# Out:
# Sepal.Length     float64
# Sepal.Width      float64
# Petal.Length     float64
# Petal.Width      float64
# Species         category
# dtype: object

# %%
iris = iris >> mutate(across(where(is_categorical), as_character))
iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), mean, na_rm=True)
)
# Out:
#       Species  Sepal.Length  Sepal.Width
# 0      setosa         5.006        3.428
# 1  versicolor         5.936        2.770
# 2   virginica         6.588        2.974

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), dict(mean=mean, sd=sd))
)
# Out:
#       Species Sepal.Length_mean  Sepal.Length_sd  Sepal.Width_mean  \
# 0      setosa               NaN         0.352490             3.428
# 1  versicolor               NaN         0.516171             2.770
# 2   virginica               NaN         0.635880             2.974
#
#    Sepal.Width_sd
# 0        0.379064
# 1        0.313798
# 2        0.322497

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), mean, _names = "mean_{_col}")
)
# Out:
#       Species mean_Sepal.Length  mean_Sepal.Width
# 0      setosa               NaN             3.428
# 1  versicolor               NaN             2.770
# 2   virginica               NaN             2.974

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), dict(mean=mean, sd=sd), _names = "{_col}.{_fn}")
)
# Out:
#       Species Sepal.Length.mean  Sepal.Length.sd  Sepal.Width.mean  \
# 0      setosa               NaN         0.352490             3.428
# 1  versicolor               NaN         0.516171             2.770
# 2   virginica               NaN         0.635880             2.974
#
#    Sepal.Width.sd
# 0        0.379064
# 1        0.313798
# 2        0.322497

# %%
iris >> group_by(f.Species) >> summarise(
    across(starts_with("Sepal"), [mean, sd], _names = "{_col}.fn{_fn}")
)
# Out:
#       Species Sepal.Length.fn1  Sepal.Length.fn2  Sepal.Width.fn1  \
# 0      setosa              NaN          0.352490            3.428
# 1  versicolor              NaN          0.516171            2.770
# 2   virginica              NaN          0.635880            2.974
#
#    Sepal.Width.fn2
# 0         0.379064
# 1         0.313798
# 2         0.322497

# %%
runif = numpy.random.default_rng(8525).random
df = DataFrame(dict(
    id=[1, 2, 3, 4], 
    w=runif(4), 
    x=runif(4), 
    y=runif(4), 
    z=runif(4)
))
df >> rowwise() >> mutate(
    sum = c_across(f[f.w:f.z], sum), # function has to be called inside c_across
    sd = c_across(f[f.w:f.z], sd)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-a86ebee28d4d> in <module>
#       9 df >> rowwise() >> mutate(
#      10     sum = c_across(f[f.w:f.z], sum), # function has to be called inside c_across
# ---> 11     sd = c_across(f[f.w:f.z], sd)
#      12 )
#
# ~/github/pipda/pipda/function.py in evaluate(self, data, context)
#      61         if not context:
#      62             # leave args/kwargs for the verb/function/operator to evaluate
# ---> 63             return self.func(data, *self.args, **self.kwargs)
#      64
#      65         args = evaluate_args(self.args, data, context.args)
#
# ~/miniconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/github/plyrda/plyrda/verbs.py in mutate(_data, _keep, _before, _after, *acrosses, **kwargs)
#     103
#     104     if isinstance(_data, RowwiseDataFrame):
# --> 105         data = RowwiseDataFrame(_data, _data.rowwise)
#     106     else:
#     107         data = copy_df(_data)
#
# ~/github/plyrda/plyrda/middlewares.py in __init__(self, rowwise, *args, **kwargs)
#     189     ) -> None:
#     190         self.__dict__['rowwise'] = rowwise or True
# --> 191         super().__init__(*args, **kwargs)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     523
#     524             mgr = self._init_mgr(
# --> 525                 data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     526             )
#     527
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _init_mgr(cls, mgr, axes, dtype, copy)
#     208         for a, axe in axes.items():
#     209             if axe is not None:
# --> 210                 axe = ensure_index(axe)
#     211                 bm_axis = cls._get_block_manager_axis(a)
#     212                 mgr = mgr.reindex_axis(axe, axis=bm_axis, copy=False)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, True was passed
