# %%
# https://dplyr.tidyverse.org/reference/with_groups.html

from datar.all import *

# %%
df = tibble(g=c(1, 1, 2, 2, 3), x=runif(5))
df >> with_groups(f.g, mutate, x_mean = mean(f.x)) >> ungroup()
# Out:
#    g         x    x_mean
# 0  1  0.721216  0.786010
# 1  1  0.850803  0.786010
# 2  2  0.652710  0.547958
# 3  2  0.443206  0.547958
# 4  3  0.925987  0.925987

# %%
df >> with_groups(f.g, lambda df: df >> mutate(x1 = first(f.x))) >> ungroup()
# Out:
#    g         x        x1
# 0  1  0.721216  0.721216
# 1  1  0.850803  0.721216
# 2  2  0.652710  0.652710
# 3  2  0.443206  0.652710
# 4  3  0.925987  0.925987

# %%
df >> \
  group_by(f.g) >> \
  with_groups(None, mutate, x_mean = mean(f.x))
# Out:
#    g         x    x_mean
# 0  1  0.721216  0.718784
# 1  1  0.850803  0.718784
# 2  2  0.652710  0.718784
# 3  2  0.443206  0.718784
# 4  3  0.925987  0.718784

# %%
df >> \
  group_by(f.g) >> \
  with_groups(None, mutate, g=None)
# Out:
#           x
# 0  0.721216
# 1  0.850803
# 2  0.652710
# 3  0.443206
# 4  0.925987
