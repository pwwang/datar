# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# https://dplyr.tidyverse.org/reference/mutate.html
from plyrda.data import starwars
from plyrda.all import *

# %%
starwars >> \
 select(f.name, f.mass) >> \
 mutate(
  mass2 = f.mass * 2,
  mass2_squared = f.mass2 * f.mass2
)
# Out:
#               name   mass  mass2  mass2_squared
# 0   Luke Skywalker   77.0  154.0        23716.0
# 1            C-3PO   75.0  150.0        22500.0
# 2            R2-D2   32.0   64.0         4096.0
# 3      Darth Vader  136.0  272.0        73984.0
# 4      Leia Organa   49.0   98.0         9604.0
# ..             ...    ...    ...            ...
# 82             Rey    NaN    NaN            NaN
# 83     Poe Dameron    NaN    NaN            NaN
# 84             BB8    NaN    NaN            NaN
# 85  Captain Phasma    NaN    NaN            NaN
# 86   Padmé Amidala   45.0   90.0         8100.0
#
# [87 rows x 4 columns]

# %%
starwars >> \
 select(f.name, f.height, f.mass, f.homeworld) >> \
 mutate(
  mass = None,
  height = f.height * 0.0328084 # convert to feet
)
# Out:
#               name    height homeworld
# 0   Luke Skywalker  5.643045  Tatooine
# 1            C-3PO  5.479003  Tatooine
# 2            R2-D2  3.149606     Naboo
# 3      Darth Vader  6.627297  Tatooine
# 4      Leia Organa  4.921260  Alderaan
# ..             ...       ...       ...
# 82             Rey       NaN       NaN
# 83     Poe Dameron       NaN       NaN
# 84             BB8       NaN       NaN
# 85  Captain Phasma       NaN       NaN
# 86   Padmé Amidala  5.413386     Naboo
#
# [87 rows x 3 columns]

# %%
x = starwars >> \
 select(f.name, f.homeworld, f.species) >> \
 mutate(across(~f.name, as_categorical))

x.dtypes
x
# Out:
# name           object
# homeworld    category
# species      category
# dtype: object
#               name homeworld species
# 0   Luke Skywalker  Tatooine   Human
# 1            C-3PO  Tatooine   Droid
# 2            R2-D2     Naboo   Droid
# 3      Darth Vader  Tatooine   Human
# 4      Leia Organa  Alderaan   Human
# ..             ...       ...     ...
# 82             Rey       NaN   Human
# 83     Poe Dameron       NaN   Human
# 84             BB8       NaN   Droid
# 85  Captain Phasma       NaN     NaN
# 86   Padmé Amidala     Naboo   Human
#
# [87 rows x 3 columns]

# %%
starwars >> \
 select(f.name, f.mass, f.homeworld) >> \
 group_by(f.homeworld) >> \
 mutate(rank=min_rank(desc(f.mass)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0b4d0e8febd1> in <module>
#       2  select(f.name, f.mass, f.homeworld) >> \
#       3  group_by(f.homeworld) >> \
# ----> 4  mutate(rank=min_rank(desc(f.mass)))
#
# ~/github/pipda/pipda/function.py in evaluate(self, data, context)
#      61         if not context:
#      62             # leave args/kwargs for the verb/function/operator to evaluate
# ---> 63             return self.func(data, *self.args, **self.kwargs)
#      64
#      65         args = evaluate_args(self.args, data, context.args)
#
# ~/miniconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/github/plyrda/plyrda/verbs.py in _(_data, _keep, _before, _after, *acrosses, **kwargs)
#     164         _before=_before,
#     165         _after=_after,
# --> 166         **kwargs
#     167     )
#     168     return ret.groupby(_data.keys)
#
# ~/github/pipda/pipda/verb.py in wrapper(_force_piping, *args, **kwargs)
#      90             return Verb(generic, context, args, kwargs)
#      91
# ---> 92         return func(*args, **kwargs)
#      93
#      94     wrapper.register = generic.register
#
# ~/github/plyrda/plyrda/verbs.py in mutate(_data, _keep, _before, _after, *acrosses, **kwargs)
#     111             data.drop(columns=[key], inplace=True)
#     112             continue
# --> 113         val = evaluate_expr(val, data, context)
#     114         if isinstance(val, CAcross):
#     115             val.names = key
#
# ~/github/pipda/pipda/utils.py in evaluate_expr(expr, data, context)
#     180         ret = (expr.evaluate(data, context)
#     181                if not expr.context
# --> 182                else expr.evaluate(data))
#     183         return ret
#     184     return expr
#
# ~/github/pipda/pipda/function.py in evaluate(self, data, context)
#      65         args = evaluate_args(self.args, data, context.args)
#      66         kwargs = evaluate_kwargs(self.kwargs, data, context.kwargs)
# ---> 67         return self.func(data, *args, **kwargs)
#      68
#      69 def _register_function_no_datarg(context: Optional[Union[ContextBase, int]],
#
# ~/miniconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/github/plyrda/plyrda/funcs.py in wrapper(_data, column, *args, **kwargs)
#      52             )
#      53
# ---> 54         return func(_data[columns].values.flatten(), *args, **kwargs)
#      55
#      56     @wrapper.register(DataFrameGroupBy)
#
# NameError: name 'columns' is not defined
