# %%
# https://dplyr.tidyverse.org/reference/slice.html

from datar.datasets import mtcars
from datar.all import *

# %run nb_helpers.py
nb_header(slice, slice_head, slice_max, slice_min, slice_sample, slice_tail)
# Out:
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "min" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "max" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "sum" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "abs" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "round" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "all" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "any" has been overriden by datar.
# [2021-07-07 00:20:43][datar][WARNING] Builtin name "re" has been overriden by datar.
# [2021-07-07 00:20:44][datar][WARNING] Builtin name "filter" has been overriden by datar.
# [2021-07-07 00:20:44][datar][WARNING] Builtin name "slice" has been overriden by datar.
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/93d069f3ca36711fc811c61dcf60e9fc3d1460a5?filepath=docs%2Fnotebooks%2Fslice.ipynb">binder</a>.</div>
# ### # slice
# ##### Index rows by their (integer) locations
#
# Original APIs https://dplyr.tidyverse.org/reference/slice.html
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe
# &emsp;&emsp;`rows`: The indexes
# &emsp;&emsp;&emsp;&emsp;Ranges can be specified as `f[1:3]`
# &emsp;&emsp;&emsp;&emsp;Note that the negatives mean differently than in dplyr.
# &emsp;&emsp;&emsp;&emsp;In dplyr, negative numbers meaning exclusive, but here negative
# &emsp;&emsp;&emsp;&emsp;numbers are negative indexes like how they act in python indexing.
# &emsp;&emsp;&emsp;&emsp;For exclusive indexes, you need to use inversion. For example:
# &emsp;&emsp;&emsp;&emsp;`slice(df, ~f[:3])` excludes first 3 rows. You can also do:
# &emsp;&emsp;&emsp;&emsp;`slice(df, ~c(f[:3], 6))` to exclude multiple set of rows.
# &emsp;&emsp;&emsp;&emsp;To exclude a single row, you can't do this directly: `slice(df, ~1)`
# &emsp;&emsp;&emsp;&emsp;since `~1` is directly compiled into a number. You can do this
#
# &emsp;&emsp;&emsp;&emsp;`instead`: `slice(df, ~c(1))`
#
# &emsp;&emsp;&emsp;&emsp;Exclusive and inclusive expressions are allowed to be mixed, unlike
# &emsp;&emsp;&emsp;&emsp;in `dplyr`. They are expanded in the order they are passed in.
#
# &emsp;&emsp;`_preserve`: Relevant when the _data input is grouped.
# &emsp;&emsp;&emsp;&emsp;If _preserve = FALSE (the default), the grouping structure is
# &emsp;&emsp;&emsp;&emsp;recalculated based on the resulting data,
# &emsp;&emsp;&emsp;&emsp;otherwise the grouping is kept as is.
#
# &emsp;&emsp;`base0_`: If rows are selected by indexes, whether they are 0-based.
# &emsp;&emsp;&emsp;&emsp;If not provided, `datar.base.get_option('index.base.0')` is used.
#
# ##### Returns:
# &emsp;&emsp;The sliced dataframe
# ### # slice_head
# ##### Select first rows
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe.
# &emsp;&emsp;`n`: and
# &emsp;&emsp;`prop`: Provide either n, the number of rows, or prop, the proportion of
# &emsp;&emsp;&emsp;&emsp;rows to select.
# &emsp;&emsp;&emsp;&emsp;If neither are supplied, n = 1 will be used.
# &emsp;&emsp;&emsp;&emsp;If n is greater than the number of rows in the group (or prop > 1),
# &emsp;&emsp;&emsp;&emsp;the result will be silently truncated to the group size.
# &emsp;&emsp;&emsp;&emsp;If the proportion of a group size is not an integer,
# &emsp;&emsp;&emsp;&emsp;it is rounded down.
#
# ##### Returns:
# &emsp;&emsp;The sliced dataframe
# ### # slice_max
# ##### select rows with highest values of a variable.
#
# See Also:
# &emsp;&emsp;[`slice_head()`](datar.dplyr.slice.slice_head)
# ### # slice_min
# ##### select rows with lowest values of a variable.
#
# See Also:
# &emsp;&emsp;[`slice_head()`](datar.dplyr.slice.slice_head)
# ### # slice_sample
# ##### Randomly selects rows.
#
# See Also:
# &emsp;&emsp;[`slice_head()`](datar.dplyr.slice.slice_head)
# ### # slice_tail
# ##### Select last rows
#
# See Also:
# &emsp;&emsp;[`slice_head()`](datar.dplyr.slice.slice_head)

# %%
mtcars >> slice(1) # 1-based by default
# Out:
#                 mpg     cyl      disp      hp      drat        wt      qsec  \
#           <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Mazda RX4      21.0       6     160.0     110       3.9      2.62     16.46
#
#                vs      am    gear    carb
#           <int64> <int64> <int64> <int64>
# Mazda RX4       0       1       4       4

# %%
mtcars >> slice(n()) # last row
# Out:
#                  mpg     cyl      disp      hp      drat        wt      qsec  \
#            <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Volvo 142E      21.4       4     121.0     109      4.11      2.78      18.6
#
#                 vs      am    gear    carb
#            <int64> <int64> <int64> <int64>
# Volvo 142E       1       1       4       2

# %%
# or
mtcars >> slice(-1) # for both 0-based and 1-based
# Out:
#                  mpg     cyl      disp      hp      drat        wt      qsec  \
#            <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Volvo 142E      21.4       4     121.0     109      4.11      2.78      18.6
#
#                 vs      am    gear    carb
#            <int64> <int64> <int64> <int64>
# Volvo 142E       1       1       4       2

# %%
mtcars >> slice(f[5:n()])
# Out:
#                           mpg     cyl      disp      hp      drat        wt  \
#                     <float64> <int64> <float64> <int64> <float64> <float64>
# Hornet Sportabout        18.7       8     360.0     175      3.15     3.440
# Valiant                  18.1       6     225.0     105      2.76     3.460
# Duster 360               14.3       8     360.0     245      3.21     3.570
# Merc 240D                24.4       4     146.7      62      3.69     3.190
# Merc 230                 22.8       4     140.8      95      3.92     3.150
# Merc 280                 19.2       6     167.6     123      3.92     3.440
# Merc 280C                17.8       6     167.6     123      3.92     3.440
# Merc 450SE               16.4       8     275.8     180      3.07     4.070
# Merc 450SL               17.3       8     275.8     180      3.07     3.730
# Merc 450SLC              15.2       8     275.8     180      3.07     3.780
# Cadillac Fleetwood       10.4       8     472.0     205      2.93     5.250
# Lincoln Continental      10.4       8     460.0     215      3.00     5.424
# Chrysler Imperial        14.7       8     440.0     230      3.23     5.345
# Fiat 128                 32.4       4      78.7      66      4.08     2.200
# Honda Civic              30.4       4      75.7      52      4.93     1.615
# Toyota Corolla           33.9       4      71.1      65      4.22     1.835
# Toyota Corona            21.5       4     120.1      97      3.70     2.465
# Dodge Challenger         15.5       8     318.0     150      2.76     3.520
# AMC Javelin              15.2       8     304.0     150      3.15     3.435
# Camaro Z28               13.3       8     350.0     245      3.73     3.840
# Pontiac Firebird         19.2       8     400.0     175      3.08     3.845
# Fiat X1-9                27.3       4      79.0      66      4.08     1.935
# Porsche 914-2            26.0       4     120.3      91      4.43     2.140
# Lotus Europa             30.4       4      95.1     113      3.77     1.513
# Ford Pantera L           15.8       8     351.0     264      4.22     3.170
# Ferrari Dino             19.7       6     145.0     175      3.62     2.770
# Maserati Bora            15.0       8     301.0     335      3.54     3.570
# Volvo 142E               21.4       4     121.0     109      4.11     2.780
#
#                          qsec      vs      am    gear    carb
#                     <float64> <int64> <int64> <int64> <int64>
# Hornet Sportabout       17.02       0       0       3       2
# Valiant                 20.22       1       0       3       1
# Duster 360              15.84       0       0       3       4
# Merc 240D               20.00       1       0       4       2
# Merc 230                22.90       1       0       4       2
# Merc 280                18.30       1       0       4       4
# Merc 280C               18.90       1       0       4       4
# Merc 450SE              17.40       0       0       3       3
# Merc 450SL              17.60       0       0       3       3
# Merc 450SLC             18.00       0       0       3       3
# Cadillac Fleetwood      17.98       0       0       3       4
# Lincoln Continental     17.82       0       0       3       4
# Chrysler Imperial       17.42       0       0       3       4
# Fiat 128                19.47       1       1       4       1
# Honda Civic             18.52       1       1       4       2
# Toyota Corolla          19.90       1       1       4       1
# Toyota Corona           20.01       1       0       3       1
# Dodge Challenger        16.87       0       0       3       2
# AMC Javelin             17.30       0       0       3       2
# Camaro Z28              15.41       0       0       3       4
# Pontiac Firebird        17.05       0       0       3       2
# Fiat X1-9               18.90       1       1       4       1
# Porsche 914-2           16.70       0       1       5       2
# Lotus Europa            16.90       1       1       5       2
# Ford Pantera L          14.50       0       1       5       4
# Ferrari Dino            15.50       0       1       5       6
# Maserati Bora           14.60       0       1       5       8
# Volvo 142E              18.60       1       1       4       2

# %%
# or
mtcars >> slice(~f[:4])
# Out:
#                           mpg     cyl      disp      hp      drat        wt  \
#                     <float64> <int64> <float64> <int64> <float64> <float64>
# Hornet Sportabout        18.7       8     360.0     175      3.15     3.440
# Valiant                  18.1       6     225.0     105      2.76     3.460
# Duster 360               14.3       8     360.0     245      3.21     3.570
# Merc 240D                24.4       4     146.7      62      3.69     3.190
# Merc 230                 22.8       4     140.8      95      3.92     3.150
# Merc 280                 19.2       6     167.6     123      3.92     3.440
# Merc 280C                17.8       6     167.6     123      3.92     3.440
# Merc 450SE               16.4       8     275.8     180      3.07     4.070
# Merc 450SL               17.3       8     275.8     180      3.07     3.730
# Merc 450SLC              15.2       8     275.8     180      3.07     3.780
# Cadillac Fleetwood       10.4       8     472.0     205      2.93     5.250
# Lincoln Continental      10.4       8     460.0     215      3.00     5.424
# Chrysler Imperial        14.7       8     440.0     230      3.23     5.345
# Fiat 128                 32.4       4      78.7      66      4.08     2.200
# Honda Civic              30.4       4      75.7      52      4.93     1.615
# Toyota Corolla           33.9       4      71.1      65      4.22     1.835
# Toyota Corona            21.5       4     120.1      97      3.70     2.465
# Dodge Challenger         15.5       8     318.0     150      2.76     3.520
# AMC Javelin              15.2       8     304.0     150      3.15     3.435
# Camaro Z28               13.3       8     350.0     245      3.73     3.840
# Pontiac Firebird         19.2       8     400.0     175      3.08     3.845
# Fiat X1-9                27.3       4      79.0      66      4.08     1.935
# Porsche 914-2            26.0       4     120.3      91      4.43     2.140
# Lotus Europa             30.4       4      95.1     113      3.77     1.513
# Ford Pantera L           15.8       8     351.0     264      4.22     3.170
# Ferrari Dino             19.7       6     145.0     175      3.62     2.770
# Maserati Bora            15.0       8     301.0     335      3.54     3.570
# Volvo 142E               21.4       4     121.0     109      4.11     2.780
#
#                          qsec      vs      am    gear    carb
#                     <float64> <int64> <int64> <int64> <int64>
# Hornet Sportabout       17.02       0       0       3       2
# Valiant                 20.22       1       0       3       1
# Duster 360              15.84       0       0       3       4
# Merc 240D               20.00       1       0       4       2
# Merc 230                22.90       1       0       4       2
# Merc 280                18.30       1       0       4       4
# Merc 280C               18.90       1       0       4       4
# Merc 450SE              17.40       0       0       3       3
# Merc 450SL              17.60       0       0       3       3
# Merc 450SLC             18.00       0       0       3       3
# Cadillac Fleetwood      17.98       0       0       3       4
# Lincoln Continental     17.82       0       0       3       4
# Chrysler Imperial       17.42       0       0       3       4
# Fiat 128                19.47       1       1       4       1
# Honda Civic             18.52       1       1       4       2
# Toyota Corolla          19.90       1       1       4       1
# Toyota Corona           20.01       1       0       3       1
# Dodge Challenger        16.87       0       0       3       2
# AMC Javelin             17.30       0       0       3       2
# Camaro Z28              15.41       0       0       3       4
# Pontiac Firebird        17.05       0       0       3       2
# Fiat X1-9               18.90       1       1       4       1
# Porsche 914-2           16.70       0       1       5       2
# Lotus Europa            16.90       1       1       5       2
# Ford Pantera L          14.50       0       1       5       4
# Ferrari Dino            15.50       0       1       5       6
# Maserati Bora           14.60       0       1       5       8
# Volvo 142E              18.60       1       1       4       2

# %%
mtcars >> slice(-f[:4])
# Out:
#                      mpg     cyl      disp      hp      drat        wt  \
#                <float64> <int64> <float64> <int64> <float64> <float64>
# Ford Pantera L      15.8       8     351.0     264      4.22      3.17
# Ferrari Dino        19.7       6     145.0     175      3.62      2.77
# Maserati Bora       15.0       8     301.0     335      3.54      3.57
# Volvo 142E          21.4       4     121.0     109      4.11      2.78
#
#                     qsec      vs      am    gear    carb
#                <float64> <int64> <int64> <int64> <int64>
# Ford Pantera L      14.5       0       1       5       4
# Ferrari Dino        15.5       0       1       5       6
# Maserati Bora       14.6       0       1       5       8
# Volvo 142E          18.6       1       1       4       2

# %%
mtcars >> slice_head(n=5)
# Out:
#                         mpg     cyl      disp      hp      drat        wt  \
#                   <float64> <int64> <float64> <int64> <float64> <float64>
# Mazda RX4              21.0       6     160.0     110      3.90     2.620
# Mazda RX4 Wag          21.0       6     160.0     110      3.90     2.875
# Datsun 710             22.8       4     108.0      93      3.85     2.320
# Hornet 4 Drive         21.4       6     258.0     110      3.08     3.215
# Hornet Sportabout      18.7       8     360.0     175      3.15     3.440
#
#                        qsec      vs      am    gear    carb
#                   <float64> <int64> <int64> <int64> <int64>
# Mazda RX4             16.46       0       1       4       4
# Mazda RX4 Wag         17.02       0       1       4       4
# Datsun 710            18.61       1       1       4       1
# Hornet 4 Drive        19.44       1       0       3       1
# Hornet Sportabout     17.02       0       0       3       2

# %%
mtcars >> slice_tail(n=5)
# Out:
#                      mpg     cyl      disp      hp      drat        wt  \
#                <float64> <int64> <float64> <int64> <float64> <float64>
# Lotus Europa        30.4       4      95.1     113      3.77     1.513
# Ford Pantera L      15.8       8     351.0     264      4.22     3.170
# Ferrari Dino        19.7       6     145.0     175      3.62     2.770
# Maserati Bora       15.0       8     301.0     335      3.54     3.570
# Volvo 142E          21.4       4     121.0     109      4.11     2.780
#
#                     qsec      vs      am    gear    carb
#                <float64> <int64> <int64> <int64> <int64>
# Lotus Europa        16.9       1       1       5       2
# Ford Pantera L      14.5       0       1       5       4
# Ferrari Dino        15.5       0       1       5       6
# Maserati Bora       14.6       0       1       5       8
# Volvo 142E          18.6       1       1       4       2

# %%
mtcars >> slice_min(f.mpg, n=5)
# Out:
#                           mpg     cyl      disp      hp      drat        wt  \
#                     <float64> <int64> <float64> <int64> <float64> <float64>
# Cadillac Fleetwood       10.4       8     472.0     205      2.93     5.250
# Lincoln Continental      10.4       8     460.0     215      3.00     5.424
# Camaro Z28               13.3       8     350.0     245      3.73     3.840
# Duster 360               14.3       8     360.0     245      3.21     3.570
# Chrysler Imperial        14.7       8     440.0     230      3.23     5.345
#
#                          qsec      vs      am    gear    carb
#                     <float64> <int64> <int64> <int64> <int64>
# Cadillac Fleetwood      17.98       0       0       3       4
# Lincoln Continental     17.82       0       0       3       4
# Camaro Z28              15.41       0       0       3       4
# Duster 360              15.84       0       0       3       4
# Chrysler Imperial       17.42       0       0       3       4

# %%
mtcars >> slice_max(f.mpg, n=5)
# Out:
#                      mpg     cyl      disp      hp      drat        wt  \
#                <float64> <int64> <float64> <int64> <float64> <float64>
# Toyota Corolla      33.9       4      71.1      65      4.22     1.835
# Fiat 128            32.4       4      78.7      66      4.08     2.200
# Honda Civic         30.4       4      75.7      52      4.93     1.615
# Lotus Europa        30.4       4      95.1     113      3.77     1.513
# Fiat X1-9           27.3       4      79.0      66      4.08     1.935
#
#                     qsec      vs      am    gear    carb
#                <float64> <int64> <int64> <int64> <int64>
# Toyota Corolla     19.90       1       1       4       1
# Fiat 128           19.47       1       1       4       1
# Honda Civic        18.52       1       1       4       2
# Lotus Europa       16.90       1       1       5       2
# Fiat X1-9          18.90       1       1       4       1

# %%
mtcars >> slice_min(f.cyl, n=1)
# Out:
#                      mpg     cyl      disp      hp      drat        wt  \
#                <float64> <int64> <float64> <int64> <float64> <float64>
# Datsun 710          22.8       4     108.0      93      3.85     2.320
# Merc 240D           24.4       4     146.7      62      3.69     3.190
# Merc 230            22.8       4     140.8      95      3.92     3.150
# Fiat 128            32.4       4      78.7      66      4.08     2.200
# Honda Civic         30.4       4      75.7      52      4.93     1.615
# Toyota Corolla      33.9       4      71.1      65      4.22     1.835
# Toyota Corona       21.5       4     120.1      97      3.70     2.465
# Fiat X1-9           27.3       4      79.0      66      4.08     1.935
# Porsche 914-2       26.0       4     120.3      91      4.43     2.140
# Lotus Europa        30.4       4      95.1     113      3.77     1.513
# Volvo 142E          21.4       4     121.0     109      4.11     2.780
#
#                     qsec      vs      am    gear    carb
#                <float64> <int64> <int64> <int64> <int64>
# Datsun 710         18.61       1       1       4       1
# Merc 240D          20.00       1       0       4       2
# Merc 230           22.90       1       0       4       2
# Fiat 128           19.47       1       1       4       1
# Honda Civic        18.52       1       1       4       2
# Toyota Corolla     19.90       1       1       4       1
# Toyota Corona      20.01       1       0       3       1
# Fiat X1-9          18.90       1       1       4       1
# Porsche 914-2      16.70       0       1       5       2
# Lotus Europa       16.90       1       1       5       2
# Volvo 142E         18.60       1       1       4       2

# %%
mtcars >> slice_min(f.cyl, n=1, with_ties=False)
# Out:
#                  mpg     cyl      disp      hp      drat        wt      qsec  \
#            <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Datsun 710      22.8       4     108.0      93      3.85      2.32     18.61
#
#                 vs      am    gear    carb
#            <int64> <int64> <int64> <int64>
# Datsun 710       1       1       4       1

# %%
mtcars >> slice_min(f.cyl, n=1, with_ties='last')
# Out:
#                  mpg     cyl      disp      hp      drat        wt      qsec  \
#            <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Volvo 142E      21.4       4     121.0     109      4.11      2.78      18.6
#
#                 vs      am    gear    carb
#            <int64> <int64> <int64> <int64>
# Volvo 142E       1       1       4       2

# %%
mtcars >> slice_sample(n=5)
# Out:
#                          mpg     cyl      disp      hp      drat        wt  \
#                    <float64> <int64> <float64> <int64> <float64> <float64>
# Merc 450SL              17.3       8     275.8     180      3.07     3.730
# Cadillac Fleetwood      10.4       8     472.0     205      2.93     5.250
# Honda Civic             30.4       4      75.7      52      4.93     1.615
# Fiat X1-9               27.3       4      79.0      66      4.08     1.935
# Toyota Corolla          33.9       4      71.1      65      4.22     1.835
#
#                         qsec      vs      am    gear    carb
#                    <float64> <int64> <int64> <int64> <int64>
# Merc 450SL             17.60       0       0       3       3
# Cadillac Fleetwood     17.98       0       0       3       4
# Honda Civic            18.52       1       1       4       2
# Fiat X1-9              18.90       1       1       4       1
# Toyota Corolla         19.90       1       1       4       1

# %%
mtcars >> slice_sample(n=5, random_state=8525)
# Out:
#                     mpg     cyl      disp      hp      drat        wt  \
#               <float64> <int64> <float64> <int64> <float64> <float64>
# Lotus Europa       30.4       4      95.1     113      3.77     1.513
# Merc 450SL         17.3       8     275.8     180      3.07     3.730
# Porsche 914-2      26.0       4     120.3      91      4.43     2.140
# Merc 230           22.8       4     140.8      95      3.92     3.150
# Merc 240D          24.4       4     146.7      62      3.69     3.190
#
#                    qsec      vs      am    gear    carb
#               <float64> <int64> <int64> <int64> <int64>
# Lotus Europa       16.9       1       1       5       2
# Merc 450SL         17.6       0       0       3       3
# Porsche 914-2      16.7       0       1       5       2
# Merc 230           22.9       1       0       4       2
# Merc 240D          20.0       1       0       4       2

# %%
mtcars >> slice_sample(n=5, random_state=8525)
# Out:
#                     mpg     cyl      disp      hp      drat        wt  \
#               <float64> <int64> <float64> <int64> <float64> <float64>
# Lotus Europa       30.4       4      95.1     113      3.77     1.513
# Merc 450SL         17.3       8     275.8     180      3.07     3.730
# Porsche 914-2      26.0       4     120.3      91      4.43     2.140
# Merc 230           22.8       4     140.8      95      3.92     3.150
# Merc 240D          24.4       4     146.7      62      3.69     3.190
#
#                    qsec      vs      am    gear    carb
#               <float64> <int64> <int64> <int64> <int64>
# Lotus Europa       16.9       1       1       5       2
# Merc 450SL         17.6       0       0       3       3
# Porsche 914-2      16.7       0       1       5       2
# Merc 230           22.9       1       0       4       2
# Merc 240D          20.0       1       0       4       2

# %%
mtcars >> slice_sample(n=5, random_state=8525, replace=True)
# Out:
#                         mpg     cyl      disp      hp      drat        wt  \
#                   <float64> <int64> <float64> <int64> <float64> <float64>
# Dodge Challenger       15.5       8     318.0     150      2.76     3.520
# Merc 280C              17.8       6     167.6     123      3.92     3.440
# Dodge Challenger       15.5       8     318.0     150      2.76     3.520
# Chrysler Imperial      14.7       8     440.0     230      3.23     5.345
# Duster 360             14.3       8     360.0     245      3.21     3.570
#
#                        qsec      vs      am    gear    carb
#                   <float64> <int64> <int64> <int64> <int64>
# Dodge Challenger      16.87       0       0       3       2
# Merc 280C             18.90       1       0       4       4
# Dodge Challenger      16.87       0       0       3       2
# Chrysler Imperial     17.42       0       0       3       4
# Duster 360            15.84       0       0       3       4

# %%
mtcars >> slice_sample(weight_by=f.wt, n=5)
# Out:
#                         mpg     cyl      disp      hp      drat        wt  \
#                   <float64> <int64> <float64> <int64> <float64> <float64>
# Honda Civic            30.4       4      75.7      52      4.93     1.615
# AMC Javelin            15.2       8     304.0     150      3.15     3.435
# Valiant                18.1       6     225.0     105      2.76     3.460
# Hornet Sportabout      18.7       8     360.0     175      3.15     3.440
# Merc 240D              24.4       4     146.7      62      3.69     3.190
#
#                        qsec      vs      am    gear    carb
#                   <float64> <int64> <int64> <int64> <int64>
# Honda Civic           18.52       1       1       4       2
# AMC Javelin           17.30       0       0       3       2
# Valiant               20.22       1       0       3       1
# Hornet Sportabout     17.02       0       0       3       2
# Merc 240D             20.00       1       0       4       2

# %%
df = tibble(
  group=['a'] + ['b']*2 + ['c']*4,
  x=runif(7)
)
df >> group_by(f.group) >> slice_head(n=2)
# Out:
#      group         x
#   <object> <float64>
# 0        a  0.621120
# 1        b  0.643122
# 2        b  0.601806
# 3        c  0.472072
# 4        c  0.719299
#
# [Groups: group (n=3)]

# %%
df >> group_by(f.group) >> slice_head(prop = 0.5)
# Out:
#      group         x
#   <object> <float64>
# 0        b  0.643122
# 1        c  0.472072
# 2        c  0.719299
#
# [Groups: group (n=2)]

# %%
# row_number() is 1-based by default
mtcars >> filter(row_number() == 1)
# Out:
#                 mpg     cyl      disp      hp      drat        wt      qsec  \
#           <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Mazda RX4      21.0       6     160.0     110       3.9      2.62     16.46
#
#                vs      am    gear    carb
#           <int64> <int64> <int64> <int64>
# Mazda RX4       0       1       4       4

# %%
mtcars >> filter(row_number() == n() )
# Out:
#                  mpg     cyl      disp      hp      drat        wt      qsec  \
#            <float64> <int64> <float64> <int64> <float64> <float64> <float64>
# Volvo 142E      21.4       4     121.0     109      4.11      2.78      18.6
#
#                 vs      am    gear    carb
#            <int64> <int64> <int64> <int64>
# Volvo 142E       1       1       4       2

# %%
mtcars >> filter(5 <= row_number() < n()) # cannot filter
# Out:
#                           mpg     cyl      disp      hp      drat        wt  \
#                     <float64> <int64> <float64> <int64> <float64> <float64>
# Mazda RX4                21.0       6     160.0     110      3.90     2.620
# Mazda RX4 Wag            21.0       6     160.0     110      3.90     2.875
# Datsun 710               22.8       4     108.0      93      3.85     2.320
# Hornet 4 Drive           21.4       6     258.0     110      3.08     3.215
# Hornet Sportabout        18.7       8     360.0     175      3.15     3.440
# Valiant                  18.1       6     225.0     105      2.76     3.460
# Duster 360               14.3       8     360.0     245      3.21     3.570
# Merc 240D                24.4       4     146.7      62      3.69     3.190
# Merc 230                 22.8       4     140.8      95      3.92     3.150
# Merc 280                 19.2       6     167.6     123      3.92     3.440
# Merc 280C                17.8       6     167.6     123      3.92     3.440
# Merc 450SE               16.4       8     275.8     180      3.07     4.070
# Merc 450SL               17.3       8     275.8     180      3.07     3.730
# Merc 450SLC              15.2       8     275.8     180      3.07     3.780
# Cadillac Fleetwood       10.4       8     472.0     205      2.93     5.250
# Lincoln Continental      10.4       8     460.0     215      3.00     5.424
# Chrysler Imperial        14.7       8     440.0     230      3.23     5.345
# Fiat 128                 32.4       4      78.7      66      4.08     2.200
# Honda Civic              30.4       4      75.7      52      4.93     1.615
# Toyota Corolla           33.9       4      71.1      65      4.22     1.835
# Toyota Corona            21.5       4     120.1      97      3.70     2.465
# Dodge Challenger         15.5       8     318.0     150      2.76     3.520
# AMC Javelin              15.2       8     304.0     150      3.15     3.435
# Camaro Z28               13.3       8     350.0     245      3.73     3.840
# Pontiac Firebird         19.2       8     400.0     175      3.08     3.845
# Fiat X1-9                27.3       4      79.0      66      4.08     1.935
# Porsche 914-2            26.0       4     120.3      91      4.43     2.140
# Lotus Europa             30.4       4      95.1     113      3.77     1.513
# Ford Pantera L           15.8       8     351.0     264      4.22     3.170
# Ferrari Dino             19.7       6     145.0     175      3.62     2.770
# Maserati Bora            15.0       8     301.0     335      3.54     3.570
#
#                          qsec      vs      am    gear    carb
#                     <float64> <int64> <int64> <int64> <int64>
# Mazda RX4               16.46       0       1       4       4
# Mazda RX4 Wag           17.02       0       1       4       4
# Datsun 710              18.61       1       1       4       1
# Hornet 4 Drive          19.44       1       0       3       1
# Hornet Sportabout       17.02       0       0       3       2
# Valiant                 20.22       1       0       3       1
# Duster 360              15.84       0       0       3       4
# Merc 240D               20.00       1       0       4       2
# Merc 230                22.90       1       0       4       2
# Merc 280                18.30       1       0       4       4
# Merc 280C               18.90       1       0       4       4
# Merc 450SE              17.40       0       0       3       3
# Merc 450SL              17.60       0       0       3       3
# Merc 450SLC             18.00       0       0       3       3
# Cadillac Fleetwood      17.98       0       0       3       4
# Lincoln Continental     17.82       0       0       3       4
# Chrysler Imperial       17.42       0       0       3       4
# Fiat 128                19.47       1       1       4       1
# Honda Civic             18.52       1       1       4       2
# Toyota Corolla          19.90       1       1       4       1
# Toyota Corona           20.01       1       0       3       1
# Dodge Challenger        16.87       0       0       3       2
# AMC Javelin             17.30       0       0       3       2
# Camaro Z28              15.41       0       0       3       4
# Pontiac Firebird        17.05       0       0       3       2
# Fiat X1-9               18.90       1       1       4       1
# Porsche 914-2           16.70       0       1       5       2
# Lotus Europa            16.90       1       1       5       2
# Ford Pantera L          14.50       0       1       5       4
# Ferrari Dino            15.50       0       1       5       6
# Maserati Bora           14.60       0       1       5       8

# %%
mtcars >> filter(between(row_number(), 5, n()))
# Out:
#                           mpg     cyl      disp      hp      drat        wt  \
#                     <float64> <int64> <float64> <int64> <float64> <float64>
# Hornet Sportabout        18.7       8     360.0     175      3.15     3.440
# Valiant                  18.1       6     225.0     105      2.76     3.460
# Duster 360               14.3       8     360.0     245      3.21     3.570
# Merc 240D                24.4       4     146.7      62      3.69     3.190
# Merc 230                 22.8       4     140.8      95      3.92     3.150
# Merc 280                 19.2       6     167.6     123      3.92     3.440
# Merc 280C                17.8       6     167.6     123      3.92     3.440
# Merc 450SE               16.4       8     275.8     180      3.07     4.070
# Merc 450SL               17.3       8     275.8     180      3.07     3.730
# Merc 450SLC              15.2       8     275.8     180      3.07     3.780
# Cadillac Fleetwood       10.4       8     472.0     205      2.93     5.250
# Lincoln Continental      10.4       8     460.0     215      3.00     5.424
# Chrysler Imperial        14.7       8     440.0     230      3.23     5.345
# Fiat 128                 32.4       4      78.7      66      4.08     2.200
# Honda Civic              30.4       4      75.7      52      4.93     1.615
# Toyota Corolla           33.9       4      71.1      65      4.22     1.835
# Toyota Corona            21.5       4     120.1      97      3.70     2.465
# Dodge Challenger         15.5       8     318.0     150      2.76     3.520
# AMC Javelin              15.2       8     304.0     150      3.15     3.435
# Camaro Z28               13.3       8     350.0     245      3.73     3.840
# Pontiac Firebird         19.2       8     400.0     175      3.08     3.845
# Fiat X1-9                27.3       4      79.0      66      4.08     1.935
# Porsche 914-2            26.0       4     120.3      91      4.43     2.140
# Lotus Europa             30.4       4      95.1     113      3.77     1.513
# Ford Pantera L           15.8       8     351.0     264      4.22     3.170
# Ferrari Dino             19.7       6     145.0     175      3.62     2.770
# Maserati Bora            15.0       8     301.0     335      3.54     3.570
# Volvo 142E               21.4       4     121.0     109      4.11     2.780
#
#                          qsec      vs      am    gear    carb
#                     <float64> <int64> <int64> <int64> <int64>
# Hornet Sportabout       17.02       0       0       3       2
# Valiant                 20.22       1       0       3       1
# Duster 360              15.84       0       0       3       4
# Merc 240D               20.00       1       0       4       2
# Merc 230                22.90       1       0       4       2
# Merc 280                18.30       1       0       4       4
# Merc 280C               18.90       1       0       4       4
# Merc 450SE              17.40       0       0       3       3
# Merc 450SL              17.60       0       0       3       3
# Merc 450SLC             18.00       0       0       3       3
# Cadillac Fleetwood      17.98       0       0       3       4
# Lincoln Continental     17.82       0       0       3       4
# Chrysler Imperial       17.42       0       0       3       4
# Fiat 128                19.47       1       1       4       1
# Honda Civic             18.52       1       1       4       2
# Toyota Corolla          19.90       1       1       4       1
# Toyota Corona           20.01       1       0       3       1
# Dodge Challenger        16.87       0       0       3       2
# AMC Javelin             17.30       0       0       3       2
# Camaro Z28              15.41       0       0       3       4
# Pontiac Firebird        17.05       0       0       3       2
# Fiat X1-9               18.90       1       1       4       1
# Porsche 914-2           16.70       0       1       5       2
# Lotus Europa            16.90       1       1       5       2
# Ford Pantera L          14.50       0       1       5       4
# Ferrari Dino            15.50       0       1       5       6
# Maserati Bora           14.60       0       1       5       8
# Volvo 142E              18.60       1       1       4       2

# %%
df = tibble(
  group=['a']*10 + ['b']*20 + ['c']*40,
  x=runif(70)
)
df >> group_by(f.group) >> slice_min(f.x, 2)
# Out:
#      group         x
#   <object> <float64>
# 0        a  0.346350
# 1        a  0.416266
# 2        b  0.021329
# 3        b  0.040180
# 4        c  0.000400
# 5        c  0.050088
#
# [Groups: group (n=3)]

# %%
df >> group_by(f.group) >> slice_max(f.x, 2)
# Out:
#      group         x
#   <object> <float64>
# 0        a  0.991743
# 1        a  0.983114
# 2        b  0.965274
# 3        b  0.947211
# 4        c  0.931024
# 5        c  0.914770
#
# [Groups: group (n=3)]

# %%
df >> group_by(f.group) >> slice_sample(2)
# Out:
#      group         x
#   <object> <float64>
# 0        a  0.416266
# 1        a  0.528387
# 2        b  0.299559
# 3        b  0.021329
# 4        c  0.275112
# 5        c  0.659550
#
# [Groups: group (n=3)]
