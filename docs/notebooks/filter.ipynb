# %%
# https://dplyr.tidyverse.org/reference/filter.html
from datar.datasets import starwars
from datar.all import *

# %run nb_helpers.py
nb_header(filter)
# Out:
# [2021-07-16 15:27:19][datar][WARNING] Builtin name "min" has been overriden by datar.
# [2021-07-16 15:27:19][datar][WARNING] Builtin name "max" has been overriden by datar.
# [2021-07-16 15:27:19][datar][WARNING] Builtin name "sum" has been overriden by datar.
# [2021-07-16 15:27:19][datar][WARNING] Builtin name "abs" has been overriden by datar.
# [2021-07-16 15:27:19][datar][WARNING] Builtin name "round" has been overriden by datar.
# [2021-07-16 15:27:20][datar][WARNING] Builtin name "all" has been overriden by datar.
# [2021-07-16 15:27:20][datar][WARNING] Builtin name "any" has been overriden by datar.
# [2021-07-16 15:27:20][datar][WARNING] Builtin name "re" has been overriden by datar.
# [2021-07-16 15:27:20][datar][WARNING] Builtin name "filter" has been overriden by datar.
# [2021-07-16 15:27:20][datar][WARNING] Builtin name "slice" has been overriden by datar.
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/93d069f3ca36711fc811c61dcf60e9fc3d1460a5?filepath=docs%2Fnotebooks%2Ffilter.ipynb">binder</a>.</div>
# ### # filter
# ##### Subset a data frame, retaining all rows that satisfy your conditions
#
# ##### Args:
# &emsp;&emsp;`*conditions`: Expressions that return logical values
# &emsp;&emsp;`_preserve`: Relevant when the .data input is grouped.
# &emsp;&emsp;&emsp;&emsp;If _preserve = FALSE (the default), the grouping structure
# &emsp;&emsp;&emsp;&emsp;is recalculated based on the resulting data, otherwise
# &emsp;&emsp;&emsp;&emsp;the grouping is kept as is.
#
# &emsp;&emsp;`_drop_index`: Whether drop the index or not.
# &emsp;&emsp;&emsp;&emsp;When it is None and the index of _data is a RangeIndex, then
# &emsp;&emsp;&emsp;&emsp;the index is dropped.
#
# ##### Returns:
# &emsp;&emsp;The subset dataframe

# %%
filter(starwars, f.species == "Human")
# Out:
#                    name    height      mass     hair_color skin_color  \
#                <object> <float64> <float64>       <object>   <object>
# 0        Luke Skywalker     172.0      77.0          blond       fair
# 1           Darth Vader     202.0     136.0           none      white
# 2           Leia Organa     150.0      49.0          brown      light
# 3             Owen Lars     178.0     120.0    brown, grey      light
# 4    Beru Whitesun lars     165.0      75.0          brown      light
# 5     Biggs Darklighter     183.0      84.0          black      light
# 6        Obi-Wan Kenobi     182.0      77.0  auburn, white       fair
# 7      Anakin Skywalker     188.0      84.0          blond       fair
# 8        Wilhuff Tarkin     180.0       NaN   auburn, grey       fair
# 9              Han Solo     180.0      80.0          brown       fair
# 10       Wedge Antilles     170.0      77.0          brown       fair
# 11     Jek Tono Porkins     180.0     110.0          brown       fair
# 12            Palpatine     170.0      75.0           grey       pale
# 13            Boba Fett     183.0      78.2          black       fair
# 14     Lando Calrissian     177.0      79.0          black       dark
# 15                Lobot     175.0      79.0           none      light
# 16           Mon Mothma     150.0       NaN         auburn       fair
# 17         Arvel Crynyd       NaN       NaN          brown       fair
# 18         Qui-Gon Jinn     193.0      89.0          brown       fair
# 19        Finis Valorum     170.0       NaN          blond       fair
# 20       Shmi Skywalker     163.0       NaN          black       fair
# 21           Mace Windu     188.0      84.0           none       dark
# 22         Gregar Typho     185.0      85.0          black       dark
# 23                Cordé     157.0       NaN          brown      light
# 24          Cliegg Lars     183.0       NaN          brown       fair
# 25                Dormé     165.0       NaN          brown      light
# 26                Dooku     193.0      80.0          white       fair
# 27  Bail Prestor Organa     191.0       NaN          black        tan
# 28           Jango Fett     183.0      79.0          black        tan
# 29           Jocasta Nu     167.0       NaN          white       fair
# 30      Raymus Antilles     188.0      79.0          brown      light
# 31                 Finn       NaN       NaN          black       dark
# 32                  Rey       NaN       NaN          brown      light
# 33          Poe Dameron       NaN       NaN          brown      light
# 34        Padmé Amidala     165.0      45.0          brown      light
#
#     eye_color  birth_year      sex     gender     homeworld  species
#      <object>   <float64> <object>   <object>      <object> <object>
# 0        blue        19.0     male  masculine      Tatooine    Human
# 1      yellow        41.9     male  masculine      Tatooine    Human
# 2       brown        19.0   female   feminine      Alderaan    Human
# 3        blue        52.0     male  masculine      Tatooine    Human
# 4        blue        47.0   female   feminine      Tatooine    Human
# 5       brown        24.0     male  masculine      Tatooine    Human
# 6   blue-gray        57.0     male  masculine       Stewjon    Human
# 7        blue        41.9     male  masculine      Tatooine    Human
# 8        blue        64.0     male  masculine        Eriadu    Human
# 9       brown        29.0     male  masculine      Corellia    Human
# 10      hazel        21.0     male  masculine      Corellia    Human
# 11       blue         NaN     male  masculine    Bestine IV    Human
# 12     yellow        82.0     male  masculine         Naboo    Human
# 13      brown        31.5     male  masculine        Kamino    Human
# 14      brown        31.0     male  masculine       Socorro    Human
# 15       blue        37.0     male  masculine        Bespin    Human
# 16       blue        48.0   female   feminine     Chandrila    Human
# 17      brown         NaN     male  masculine           NaN    Human
# 18       blue        92.0     male  masculine           NaN    Human
# 19       blue        91.0     male  masculine     Coruscant    Human
# 20      brown        72.0   female   feminine      Tatooine    Human
# 21      brown        72.0     male  masculine    Haruun Kal    Human
# 22      brown         NaN     male  masculine         Naboo    Human
# 23      brown         NaN   female   feminine         Naboo    Human
# 24       blue        82.0     male  masculine      Tatooine    Human
# 25      brown         NaN   female   feminine         Naboo    Human
# 26      brown       102.0     male  masculine       Serenno    Human
# 27      brown        67.0     male  masculine      Alderaan    Human
# 28      brown        66.0     male  masculine  Concord Dawn    Human
# 29       blue         NaN   female   feminine     Coruscant    Human
# 30      brown         NaN     male  masculine      Alderaan    Human
# 31       dark         NaN     male  masculine           NaN    Human
# 32      hazel         NaN   female   feminine           NaN    Human
# 33      brown         NaN     male  masculine           NaN    Human
# 34      brown        46.0   female   feminine         Naboo    Human

# %%
filter(starwars, f.mass > 1000)
# Out:
#                     name    height      mass hair_color        skin_color  \
#                 <object> <float64> <float64>   <object>          <object>
# 0  Jabba Desilijic Tiure     175.0    1358.0        NaN  green-tan, brown
#
#   eye_color  birth_year             sex     gender  homeworld  species
#    <object>   <float64>        <object>   <object>   <object> <object>
# 0    orange       600.0  hermaphroditic  masculine  Nal Hutta     Hutt

# %%
# Conditions connected by & or | have to wrapped, since == has lower priority than & does
filter(starwars, (f.hair_color == "none") & (f.eye_color == "black"))
# Out:
#          name    height      mass hair_color        skin_color eye_color  \
#      <object> <float64> <float64>   <object>          <object>  <object>
# 0   Nien Nunb     160.0      68.0       none              grey     black
# 1     Gasgano     122.0       NaN       none       white, blue     black
# 2   Kit Fisto     196.0      87.0       none             green     black
# 3    Plo Koon     188.0      80.0       none            orange     black
# 4     Lama Su     229.0      88.0       none              grey     black
# 5     Taun We     213.0       NaN       none              grey     black
# 6    Shaak Ti     178.0      57.0       none  red, blue, white     black
# 7  Tion Medon     206.0      80.0       none              grey     black
# 8         BB8       NaN       NaN       none              none     black
#
#    birth_year      sex     gender    homeworld    species
#     <float64> <object>   <object>     <object>   <object>
# 0         NaN     male  masculine      Sullust  Sullustan
# 1         NaN     male  masculine      Troiken      Xexto
# 2         NaN     male  masculine  Glee Anselm   Nautolan
# 3        22.0     male  masculine        Dorin    Kel Dor
# 4         NaN     male  masculine       Kamino   Kaminoan
# 5         NaN   female   feminine       Kamino   Kaminoan
# 6         NaN   female   feminine        Shili    Togruta
# 7         NaN     male  masculine       Utapau     Pau'an
# 8         NaN     none  masculine          NaN      Droid

# %%
filter(starwars, (f.hair_color == "none") | (f.eye_color == "black"))
# Out:
#                  name    height      mass hair_color           skin_color  \
#              <object> <float64> <float64>   <object>             <object>
# 0         Darth Vader     202.0     136.0       none                white
# 1              Greedo     173.0      74.0        NaN                green
# 2               IG-88     200.0     140.0       none                metal
# 3               Bossk     190.0     113.0       none                green
# 4               Lobot     175.0      79.0       none                light
# 5              Ackbar     180.0      83.0       none         brown mottle
# 6           Nien Nunb     160.0      68.0       none                 grey
# 7         Nute Gunray     191.0      90.0       none        mottled green
# 8       Jar Jar Binks     196.0      66.0       none               orange
# 9        Roos Tarpals     224.0      82.0       none                 grey
# 10         Rugor Nass     206.0       NaN       none                green
# 11            Sebulba     112.0      40.0       none            grey, red
# 12         Darth Maul     175.0      80.0       none                  red
# 13        Bib Fortuna     180.0       NaN       none                 pale
# 14        Ayla Secura     178.0      55.0       none                 blue
# 15           Dud Bolt      94.0      45.0       none           blue, grey
# 16            Gasgano     122.0       NaN       none          white, blue
# 17     Ben Quadinaros     163.0      65.0       none  grey, green, yellow
# 18         Mace Windu     188.0      84.0       none                 dark
# 19          Kit Fisto     196.0      87.0       none                green
# 20         Adi Gallia     184.0      50.0       none                 dark
# 21        Saesee Tiin     188.0       NaN       none                 pale
# 22        Yarael Poof     264.0       NaN       none                white
# 23           Plo Koon     188.0      80.0       none               orange
# 24         Mas Amedda     196.0       NaN       none                 blue
# 25  Poggle the Lesser     183.0      80.0       none                green
# 26    Dexter Jettster     198.0     102.0       none                brown
# 27            Lama Su     229.0      88.0       none                 grey
# 28            Taun We     213.0       NaN       none                 grey
# 29      Ratts Tyerell      79.0      15.0       none           grey, blue
# 30             R4-P17      96.0       NaN       none          silver, red
# 31         Wat Tambor     193.0      48.0       none          green, grey
# 32           San Hill     191.0       NaN       none                 grey
# 33           Shaak Ti     178.0      57.0       none     red, blue, white
# 34           Grievous     216.0     159.0       none         brown, white
# 35          Sly Moore     178.0      48.0       none                 pale
# 36         Tion Medon     206.0      80.0       none                 grey
# 37                BB8       NaN       NaN       none                 none
#
#         eye_color  birth_year      sex     gender       homeworld  \
#          <object>   <float64> <object>   <object>        <object>
# 0          yellow        41.9     male  masculine        Tatooine
# 1           black        44.0     male  masculine           Rodia
# 2             red        15.0     none  masculine             NaN
# 3             red        53.0     male  masculine       Trandosha
# 4            blue        37.0     male  masculine          Bespin
# 5          orange        41.0     male  masculine        Mon Cala
# 6           black         NaN     male  masculine         Sullust
# 7             red         NaN     male  masculine  Cato Neimoidia
# 8          orange        52.0     male  masculine           Naboo
# 9          orange         NaN     male  masculine           Naboo
# 10         orange         NaN     male  masculine           Naboo
# 11         orange         NaN     male  masculine       Malastare
# 12         yellow        54.0     male  masculine        Dathomir
# 13           pink         NaN     male  masculine          Ryloth
# 14          hazel        48.0   female   feminine          Ryloth
# 15         yellow         NaN     male  masculine         Vulpter
# 16          black         NaN     male  masculine         Troiken
# 17         orange         NaN     male  masculine            Tund
# 18          brown        72.0     male  masculine      Haruun Kal
# 19          black         NaN     male  masculine     Glee Anselm
# 20           blue         NaN   female   feminine       Coruscant
# 21         orange         NaN     male  masculine         Iktotch
# 22         yellow         NaN     male  masculine         Quermia
# 23          black        22.0     male  masculine           Dorin
# 24           blue         NaN     male  masculine        Champala
# 25         yellow         NaN     male  masculine        Geonosis
# 26         yellow         NaN     male  masculine            Ojom
# 27          black         NaN     male  masculine          Kamino
# 28          black         NaN   female   feminine          Kamino
# 29        unknown         NaN     male  masculine     Aleen Minor
# 30      red, blue         NaN     none   feminine             NaN
# 31        unknown         NaN     male  masculine           Skako
# 32           gold         NaN     male  masculine      Muunilinst
# 33          black         NaN   female   feminine           Shili
# 34  green, yellow         NaN     male  masculine           Kalee
# 35          white         NaN      NaN        NaN          Umbara
# 36          black         NaN     male  masculine          Utapau
# 37          black         NaN     none  masculine             NaN
#
#          species
#         <object>
# 0          Human
# 1         Rodian
# 2          Droid
# 3     Trandoshan
# 4          Human
# 5   Mon Calamari
# 6      Sullustan
# 7      Neimodian
# 8         Gungan
# 9         Gungan
# 10        Gungan
# 11           Dug
# 12        Zabrak
# 13       Twi'lek
# 14       Twi'lek
# 15    Vulptereen
# 16         Xexto
# 17         Toong
# 18         Human
# 19      Nautolan
# 20    Tholothian
# 21      Iktotchi
# 22      Quermian
# 23       Kel Dor
# 24      Chagrian
# 25     Geonosian
# 26      Besalisk
# 27      Kaminoan
# 28      Kaminoan
# 29        Aleena
# 30         Droid
# 31       Skakoan
# 32          Muun
# 33       Togruta
# 34       Kaleesh
# 35           NaN
# 36        Pau'an
# 37         Droid

# %%
filter(starwars, f.hair_color == "none", f.eye_color == "black")
# Out:
#          name    height      mass hair_color        skin_color eye_color  \
#      <object> <float64> <float64>   <object>          <object>  <object>
# 0   Nien Nunb     160.0      68.0       none              grey     black
# 1     Gasgano     122.0       NaN       none       white, blue     black
# 2   Kit Fisto     196.0      87.0       none             green     black
# 3    Plo Koon     188.0      80.0       none            orange     black
# 4     Lama Su     229.0      88.0       none              grey     black
# 5     Taun We     213.0       NaN       none              grey     black
# 6    Shaak Ti     178.0      57.0       none  red, blue, white     black
# 7  Tion Medon     206.0      80.0       none              grey     black
# 8         BB8       NaN       NaN       none              none     black
#
#    birth_year      sex     gender    homeworld    species
#     <float64> <object>   <object>     <object>   <object>
# 0         NaN     male  masculine      Sullust  Sullustan
# 1         NaN     male  masculine      Troiken      Xexto
# 2         NaN     male  masculine  Glee Anselm   Nautolan
# 3        22.0     male  masculine        Dorin    Kel Dor
# 4         NaN     male  masculine       Kamino   Kaminoan
# 5         NaN   female   feminine       Kamino   Kaminoan
# 6         NaN   female   feminine        Shili    Togruta
# 7         NaN     male  masculine       Utapau     Pau'an
# 8         NaN     none  masculine          NaN      Droid

# %%
starwars >> filter(f.mass > mean(f.mass, na_rm=True))
# Out:
#                     name    height      mass   hair_color        skin_color  \
#                 <object> <float64> <float64>     <object>          <object>
# 0            Darth Vader     202.0     136.0         none             white
# 1              Owen Lars     178.0     120.0  brown, grey             light
# 2              Chewbacca     228.0     112.0        brown           unknown
# 3  Jabba Desilijic Tiure     175.0    1358.0          NaN  green-tan, brown
# 4       Jek Tono Porkins     180.0     110.0        brown              fair
# 5                  IG-88     200.0     140.0         none             metal
# 6                  Bossk     190.0     113.0         none             green
# 7        Dexter Jettster     198.0     102.0         none             brown
# 8               Grievous     216.0     159.0         none      brown, white
# 9                Tarfful     234.0     136.0        brown             brown
#
#        eye_color  birth_year             sex     gender   homeworld  \
#         <object>   <float64>        <object>   <object>    <object>
# 0         yellow        41.9            male  masculine    Tatooine
# 1           blue        52.0            male  masculine    Tatooine
# 2           blue       200.0            male  masculine    Kashyyyk
# 3         orange       600.0  hermaphroditic  masculine   Nal Hutta
# 4           blue         NaN            male  masculine  Bestine IV
# 5            red        15.0            none  masculine         NaN
# 6            red        53.0            male  masculine   Trandosha
# 7         yellow         NaN            male  masculine        Ojom
# 8  green, yellow         NaN            male  masculine       Kalee
# 9           blue         NaN            male  masculine    Kashyyyk
#
#       species
#      <object>
# 0       Human
# 1       Human
# 2     Wookiee
# 3        Hutt
# 4       Human
# 5       Droid
# 6  Trandoshan
# 7    Besalisk
# 8     Kaleesh
# 9     Wookiee

# %%
starwars >> group_by(f.gender) >> filter(f.mass > mean(f.mass, na_rm=True))
# Out:
#                      name    height      mass   hair_color  \
#                  <object> <float64> <float64>     <object>
# 0             Darth Vader     202.0     136.0         none
# 1               Owen Lars     178.0     120.0  brown, grey
# 2      Beru Whitesun lars     165.0      75.0        brown
# 3               Chewbacca     228.0     112.0        brown
# 4   Jabba Desilijic Tiure     175.0    1358.0          NaN
# 5        Jek Tono Porkins     180.0     110.0        brown
# 6                   IG-88     200.0     140.0         none
# 7                   Bossk     190.0     113.0         none
# 8             Ayla Secura     178.0      55.0         none
# 9         Luminara Unduli     170.0      56.2        black
# 10             Zam Wesell     168.0      55.0       blonde
# 11               Shaak Ti     178.0      57.0         none
# 12               Grievous     216.0     159.0         none
# 13                Tarfful     234.0     136.0        brown
#
#              skin_color      eye_color  birth_year             sex     gender  \
#                <object>       <object>   <float64>        <object>   <object>
# 0                 white         yellow        41.9            male  masculine
# 1                 light           blue        52.0            male  masculine
# 2                 light           blue        47.0          female   feminine
# 3               unknown           blue       200.0            male  masculine
# 4      green-tan, brown         orange       600.0  hermaphroditic  masculine
# 5                  fair           blue         NaN            male  masculine
# 6                 metal            red        15.0            none  masculine
# 7                 green            red        53.0            male  masculine
# 8                  blue          hazel        48.0          female   feminine
# 9                yellow           blue        58.0          female   feminine
# 10  fair, green, yellow         yellow         NaN          female   feminine
# 11     red, blue, white          black         NaN          female   feminine
# 12         brown, white  green, yellow         NaN            male  masculine
# 13                brown           blue         NaN            male  masculine
#
#      homeworld     species
#       <object>    <object>
# 0     Tatooine       Human
# 1     Tatooine       Human
# 2     Tatooine       Human
# 3     Kashyyyk     Wookiee
# 4    Nal Hutta        Hutt
# 5   Bestine IV       Human
# 6          NaN       Droid
# 7    Trandosha  Trandoshan
# 8       Ryloth     Twi'lek
# 9       Mirial    Mirialan
# 10       Zolan    Clawdite
# 11       Shili     Togruta
# 12       Kalee     Kaleesh
# 13    Kashyyyk     Wookiee
#
# [Groups: gender (n=2)]

# %%
# To refer to column names that are stored as strings, use `f[...]`:
vars = c("mass", "height")
cond = c(80, 150)
starwars >> \
  filter(
    f[vars[0]] > cond[0],
    f[vars[1]] > cond[1]
  )
# Out:
#                      name    height      mass   hair_color        skin_color  \
#                  <object> <float64> <float64>     <object>          <object>
# 0             Darth Vader     202.0     136.0         none             white
# 1               Owen Lars     178.0     120.0  brown, grey             light
# 2       Biggs Darklighter     183.0      84.0        black             light
# 3        Anakin Skywalker     188.0      84.0        blond              fair
# 4               Chewbacca     228.0     112.0        brown           unknown
# 5   Jabba Desilijic Tiure     175.0    1358.0          NaN  green-tan, brown
# 6        Jek Tono Porkins     180.0     110.0        brown              fair
# 7                   IG-88     200.0     140.0         none             metal
# 8                   Bossk     190.0     113.0         none             green
# 9                  Ackbar     180.0      83.0         none      brown mottle
# 10           Qui-Gon Jinn     193.0      89.0        brown              fair
# 11            Nute Gunray     191.0      90.0         none     mottled green
# 12           Roos Tarpals     224.0      82.0         none              grey
# 13             Mace Windu     188.0      84.0         none              dark
# 14           Ki-Adi-Mundi     198.0      82.0        white              pale
# 15              Kit Fisto     196.0      87.0         none             green
# 16           Gregar Typho     185.0      85.0        black              dark
# 17        Dexter Jettster     198.0     102.0         none             brown
# 18                Lama Su     229.0      88.0         none              grey
# 19               Grievous     216.0     159.0         none      brown, white
# 20                Tarfful     234.0     136.0        brown             brown
#
#         eye_color  birth_year             sex     gender       homeworld  \
#          <object>   <float64>        <object>   <object>        <object>
# 0          yellow        41.9            male  masculine        Tatooine
# 1            blue        52.0            male  masculine        Tatooine
# 2           brown        24.0            male  masculine        Tatooine
# 3            blue        41.9            male  masculine        Tatooine
# 4            blue       200.0            male  masculine        Kashyyyk
# 5          orange       600.0  hermaphroditic  masculine       Nal Hutta
# 6            blue         NaN            male  masculine      Bestine IV
# 7             red        15.0            none  masculine             NaN
# 8             red        53.0            male  masculine       Trandosha
# 9          orange        41.0            male  masculine        Mon Cala
# 10           blue        92.0            male  masculine             NaN
# 11            red         NaN            male  masculine  Cato Neimoidia
# 12         orange         NaN            male  masculine           Naboo
# 13          brown        72.0            male  masculine      Haruun Kal
# 14         yellow        92.0            male  masculine           Cerea
# 15          black         NaN            male  masculine     Glee Anselm
# 16          brown         NaN            male  masculine           Naboo
# 17         yellow         NaN            male  masculine            Ojom
# 18          black         NaN            male  masculine          Kamino
# 19  green, yellow         NaN            male  masculine           Kalee
# 20           blue         NaN            male  masculine        Kashyyyk
#
#          species
#         <object>
# 0          Human
# 1          Human
# 2          Human
# 3          Human
# 4        Wookiee
# 5           Hutt
# 6          Human
# 7          Droid
# 8     Trandoshan
# 9   Mon Calamari
# 10         Human
# 11     Neimodian
# 12        Gungan
# 13         Human
# 14        Cerean
# 15      Nautolan
# 16         Human
# 17      Besalisk
# 18      Kaminoan
# 19       Kaleesh
# 20       Wookiee
